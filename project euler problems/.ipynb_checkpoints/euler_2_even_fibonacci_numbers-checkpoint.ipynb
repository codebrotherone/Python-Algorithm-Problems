# %%
x=1
y=2
sum=0

while(y<4000000):
    if y%2==0:
        sum+=y
    # we need to do this
    # in mult. assgnment
    # python will calculate right side before
    # setting variable values
    x,y=y,x+y
    


print(sum)
# Out:
# 4613732
